# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

from matminer.utils.conversions import str_to_composition

# %%
# Retrieve NIST SCD dataset from Citrine using matminer.
# The data will be stored in the df DataFrame.

first_retrieve = False #change it to indicate first time retrieve dataset or not

from matminer.data_retrieval.retrieve_Citrine import CitrineDataRetrieval
from os import environ

if first_retrieve:
    from matminer.data_retrieval.retrieve_Citrine import CitrineDataRetrieval
    from os import environ

    api_key = environ['CITRINATION_API_KEY'] # insert your api key here
    c = CitrineDataRetrieval(api_key=api_key)
    df = c.get_dataframe(criteria={'data_set_id': '151803'})
    
    # Save downloaded dataset
    df.to_csv('NIST_CeramicDataSet.csv')
    df.to_pickle('NIST_CeramicDataSet.pkl')
else:
    df  = pd.read_pickle('NIST_CeramicDataSet.pkl')

# %%
# Get the number of samples and number of features of the dataset
df.shape
# Out:
# (4098, 161)

# %%
# Looking at the first 5 entries
df.head()

# %%
# Taking a look at a sample entry
df.loc[42,:].dropna()

# %%
# Plot a bar chart showing the 50 most common features
plt.figure(figsize=(8,16))
df.count().sort_values()[-50:].plot.barh()
plt.show()

# %%
density = df['Density'].dropna()
density = pd.to_numeric(density, errors='coerce')
density.hist(bins=100)
plt.xlabel('Density')
plt.ylabel('# of samples')
plt.show()

# %% [markdown]
# # Featurization

# %%
# Create copy of original data to not mess with them
feat = df.copy()

# %% [markdown]
# ### Make chemical formula compatible with pymatgen.core.composition

# %%
# Initialize composition column
feat['composition'] = feat['chemicalFormula']

# %%
# Check how many formulas cause an error when they are fed to pymatgen.core.composition (via str_to_composition)

N_errors, N_total = 0, 0
for entry in feat['composition']:
    try:
        pd.Series([entry]).transform(str_to_composition)
    except:
        N_errors +=1
        #print(entry)
    finally:
        N_total +=1

print('{0} errors in {1} samples'.format(N_errors, N_total))

# %%
# This function removes certain characters and expressions from a chemical formula
# so that it can be converted using pymatgen.core.composition

def make_chem_form_compatible(formula):
    
    for bad_str in ['\.','x', 'y', '\+', '\-', 'z', 'w', '\%', '\^',   # individual characters
                 'Cordierite','hisker','Sialon', # certain words that show up in some formulas
                 '\$(.*?)\$',    # LaTeX expressions
                 '\((.*?)\)',    # bracketed expressions
                 '^\d{1,2}']:    # leading numbers of 1 or 2 digits
        formula = re.sub(bad_str, '', formula)
    
    return formula

# %%
# Convert chemical formulas using above function
feat["composition"] = feat["composition"].transform(make_chem_form_compatible)

# Converting chemical formula to composition object using
# matminer.utils.conversions.str_to_composition
# which in turn uses pymatgen.core.composition
feat["composition"] = feat["composition"].transform(str_to_composition)

# %%
feat['composition']

# %% [markdown]
# ### Parse chemical formula
# #### x, y, z, and w are setted to be 0.1 (can be modified)

# %%
df1 = df.copy()
df1.loc[3892,'chemicalFormula'] = 'BN' #fix 'B-N' to 'BN'

# %%
# Parse the chemicalFormula
def formula_decompose(formula):
    '''
    decompose chemical formula 
    return
        composition: list, [(element,num),...]
            element: string
            num: string, can be math expression such as '1+0.5x'
    '''

    comp = []
    p = re.compile(r'(\d?[w-z]?)([A-Z][a-u]?)(\d*\+?\-?\d*\.?\d*[w-z]?)')

    #split the chemical formula if there is dots, but not for cases like Mg1.5x
    if re.search(r'\.', formula) and not re.search(r'\d+\.\d[w-z]', formula): 
        formula = formula.split('.')
        for item in formula:
            prefactor = '1'
            for i in re.findall(p, item):
                pre, elem, num = i
                if pre:
                    prefactor = pre
                if num == '':
                    num = '1'
                num = prefactor + '*({})'.format(num)
                comp.append((elem, num))
    else:
        prefactor = '1'
        for i in re.findall(p, formula):
            pre, elem, num = i
            if pre:
                prefactor = pre
            if num == '':
                num = '1'
            num = prefactor + '*({})'.format(num)
            comp.append((elem, num))
    return comp 

def formula_reconstruct(composition, x=0.1, y=0.1, z=0.1, w=0.1):
    '''
    reconstruct chemical formula from composition
    composition in form of [(element,num), (element,num),...]
        element: string
        num: string, can be math expression such as '1+0.5x'

    return 
        flat chemcial formula: string, such as 'Ti1.5Cu0.1Au1.0'
    '''
    flat_list = []
    for (elem, num) in composition:
        num = re.sub(r'(\d)([w-z])', r'\1*\2', num) #convert 5x to 5*x
        flat_list.append(elem)
        flat_list.append(format(eval(num), '.1f'))
    return ''.join(flat_list)
  
def formula_parser(formula):
    return formula_reconstruct(formula_decompose(formula))

# %%
df1["flatFormula"] = df1["chemicalFormula"].map(formula_parser)
df1.dropna(axis=1)
# Out:
#                       chemicalFormula                   licenses  \
# 1                                SiO2  [{'name': 'NIST_SRD-30'}]
# 2            3Al2O3.2SiO2.xZrO2.yY2O3  [{'name': 'NIST_SRD-30'}]
# 3                               Al2O3  [{'name': 'NIST_SRD-30'}]
# 4                    Si3N4.xCeO2.ySiC  [{'name': 'NIST_SRD-30'}]
# 5                               Si3N4  [{'name': 'NIST_SRD-30'}]
# 6                          ZrO2.xY2O3  [{'name': 'NIST_SRD-30'}]
# 7                          ZrO2.xY2O3  [{'name': 'NIST_SRD-30'}]
# 8                               Si3N4  [{'name': 'NIST_SRD-30'}]
# 9                                SiO2  [{'name': 'NIST_SRD-30'}]
# 10                   Si3N4.xY2O3.ySrO  [{'name': 'NIST_SRD-30'}]
# 11                                SiC  [{'name': 'NIST_SRD-30'}]
# 12                              Si3N4  [{'name': 'NIST_SRD-30'}]
# 13                              Si3N4  [{'name': 'NIST_SRD-30'}]
# 14    Si12-4.5xAl4.5xO1.5xN16-1.5xDyx  [{'name': 'NIST_SRD-30'}]
# 15                                SiC  [{'name': 'NIST_SRD-30'}]
# 16                                SiC  [{'name': 'NIST_SRD-30'}]
# 17                  Al4+2xSi2-2xO10-x  [{'name': 'NIST_SRD-30'}]
# 18                          SiC.xTiB2  [{'name': 'NIST_SRD-30'}]
# 19                                NiO  [{'name': 'NIST_SRD-30'}]
# 20                     Si6-xAlxOxN8-x  [{'name': 'NIST_SRD-30'}]
# 21                                SiC  [{'name': 'NIST_SRD-30'}]
# 22                  ZrO2.xY2O3.yFe2O3  [{'name': 'NIST_SRD-30'}]
# 23                               ZrO2  [{'name': 'NIST_SRD-30'}]
# 24                               ZrB2  [{'name': 'NIST_SRD-30'}]
# 25            Al4+2xSi2-2xO10-x.yZrO2  [{'name': 'NIST_SRD-30'}]
# 26                              Al2O3  [{'name': 'NIST_SRD-30'}]
# 27                               HfB2  [{'name': 'NIST_SRD-30'}]
# 28                                B4C  [{'name': 'NIST_SRD-30'}]
# 29                        Al2O3.xZrO2  [{'name': 'NIST_SRD-30'}]
# 30                                 BN  [{'name': 'NIST_SRD-30'}]
# ...                               ...                        ...
# 4069                         TiB2.xNi  [{'name': 'NIST_SRD-30'}]
# 4070                     3Al2O3.2SiO2  [{'name': 'NIST_SRD-30'}]
# 4071                         La2Zr2O7  [{'name': 'NIST_SRD-30'}]
# 4072                            Si3N4  [{'name': 'NIST_SRD-30'}]
# 4073                              BeO  [{'name': 'NIST_SRD-30'}]
# 4074                       ZrO2.xY2O3  [{'name': 'NIST_SRD-30'}]
# 4075                     xAl2O3.ySiO2  [{'name': 'NIST_SRD-30'}]
# 4076                      Si3N4.xY2O3  [{'name': 'NIST_SRD-30'}]
# 4077                     xAl2O3.ySiO2  [{'name': 'NIST_SRD-30'}]
# 4078                            Al2O3  [{'name': 'NIST_SRD-30'}]
# 4079                              SiC  [{'name': 'NIST_SRD-30'}]
# 4080                              AlN  [{'name': 'NIST_SRD-30'}]
# 4081                              SiC  [{'name': 'NIST_SRD-30'}]
# 4082                            Ti2O3  [{'name': 'NIST_SRD-30'}]
# 4083                              SiC  [{'name': 'NIST_SRD-30'}]
# 4084                       Al2O3.xMgO  [{'name': 'NIST_SRD-30'}]
# 4085                      HfO2.xGd2O3  [{'name': 'NIST_SRD-30'}]
# 4086                              MgO  [{'name': 'NIST_SRD-30'}]
# 4087                            Si3N4  [{'name': 'NIST_SRD-30'}]
# 4088                       BeO.xAl2O3  [{'name': 'NIST_SRD-30'}]
# 4089                             TaB2  [{'name': 'NIST_SRD-30'}]
# 4090                               BN  [{'name': 'NIST_SRD-30'}]
# 4091                            Al2O3  [{'name': 'NIST_SRD-30'}]
# 4092                Si3N4.xLa2O3.ySrO  [{'name': 'NIST_SRD-30'}]
# 4093                             ZrCx  [{'name': 'NIST_SRD-30'}]
# 4094                              AlN  [{'name': 'NIST_SRD-30'}]
# 4095                      ZrO2.xSc2O3  [{'name': 'NIST_SRD-30'}]
# 4096                 Si3N4.xMgO.yY2O3  [{'name': 'NIST_SRD-30'}]
# 4097                Al2O3.xCeO2.yZrO2  [{'name': 'NIST_SRD-30'}]
# 4098                               BN  [{'name': 'NIST_SRD-30'}]
#
#                                              references Chemical Family  \
# 1     [{'citation': 'Gaseous Corrosion of Ceramics, ...            Si-O
# 2     [{'citation': 'Thermal Diffusivity/Conductivit...     Al-Si-O:ZrO
# 3     [{'citation': 'Mechanical Properties of Pure, ...            Al-O
# 4     [{'citation': 'Effect of Silicon Carbide Whisk...        Si-N:CeO
# 5     [{'citation': 'Corrosion of Silicon Nitride Ce...            Si-N
# 6     [{'citation': 'Diffusional Creep and Kinetic D...          Zr-O:Y
# 7     [{'citation': 'Porosity-Dependence of Elastic ...          Zr-O:Y
# 8     [{'citation': 'Microhardness Load Size Effect ...            Si-N
# 9     [{'citation': 'High Temperature-Elastic Moduli...            Si-O
# 10    [{'citation': 'Ceramic Technology Project Data...      Si-N:SrO,Y
# 11    [{'citation': 'Oxidation Resistance Evaluation...            Si-C
# 12    [{'citation': 'Creep of Sintered Silicon Nitri...            Si-N
# 13    [{'citation': 'Fracture Mechanism Maps for Adv...            Si-N
# 14    [{'citation': 'Preparation and Properties of S...    Si-Al-O-N:Dy
# 15    [{'citation': 'Effect of Hot Isostatic Pressin...            Si-C
# 16    [{'citation': 'Elastic Properties of SiC, AlN,...            Si-C
# 17    [{'citation': 'Structure Refinement of Mullite...         Al-Si-O
# 18    [{'citation': 'In Situ Enhancement of Toughnes...        Si-C:TiB
# 19    [{'citation': 'Thermal Constants for Ni, NiO, ...            Ni-O
# 20    [{'citation': 'Static Fatigue and Creep Resist...       Si-Al-O-N
# 21    [{'citation': 'Strength Distributions of SiC C...        Si-C:B,C
# 22    [{'citation': 'Elastic Constants of the Iron O...          Zr-O:Y
# 23    [{'citation': 'Effects of Environment on the M...         Zr-O:Al
# 24    [{'citation': 'Elastic Properties of Polycryst...            Zr-B
# 25    [{'citation': 'High-Temperature Characterizati...     Al-Si-O:ZrO
# 26    [{'citation': 'Sliding Friction of Ceramics:  ...            Al-O
# 27    [{'citation': 'Elastic Properties of Polycryst...            Hf-B
# 28    [{'citation': 'Electrophysical Properties of P...             B-C
# 29    [{'citation': 'Creep Behaviour of Alumina, Zir...        Al-O:ZrO
# 30    [{'citation': 'Synthesis of Polycrystalline Cu...             B-N
# ...                                                 ...             ...
# 4069  [{'citation': 'Effect of Microstructure on the...         Ti-B:Ni
# 4070  [{'citation': 'Creep Deformation of Polycrysta...         Al-Si-O
# 4071  [{'citation': 'Zirconates as New Materials for...         La-Zr-O
# 4072  [{'citation': 'Sintering Behavior and Properti...            Si-N
# 4073  [{'citation': 'Rigidity Modulus of Some Pure O...            Be-O
# 4074  [{'citation': 'Influence of Fracture Toughness...          Zr-O:Y
# 4075  [{'citation': 'High Temperature Mechanical Pro...         Al-Si-O
# 4076  [{'citation': 'Ceramic Technology Project Data...          Si-N:Y
# 4077  [{'citation': 'Static Fatigue and Fracture Tou...         Al-Si-O
# 4078  [{'citation': 'Effect of Porosity on the Erosi...            Al-O
# 4079  [{'citation': 'Mechanical Property Evaluation ...            Si-C
# 4080  [{'citation': 'Temperature Dependence of the T...          Al-N:Y
# 4081  [{'citation': 'Performance Verification of New...            Si-C
# 4082  [{'citation': 'High-Temperature Heat Contents ...            Ti-O
# 4083  [{'citation': 'Part 1: An Introduction for the...         Si-C:Al
# 4084  [{'citation': 'Microstructure and Mechanical P...         Al-O:Mg
# 4085  [{'citation': 'Elastic Properties of Stabilize...         Hf-O:Gd
# 4086  [{'citation': 'Thermal Constants for Ni, NiO, ...            Mg-O
# 4087  [{'citation': 'Effects of Environment on the M...          Si-N:Y
# 4088  [{'citation': 'Mechanical Behaviour of Polycry...         Be-O:Al
# 4089  [{'citation': 'Engineering Properties of Borid...            Ta-B
# 4090  [{'citation': 'Low-Temperature Heat Capacity o...             B-N
# 4091  [{'citation': 'Elevated-Temperature Toughness ...            Al-O
# 4092  [{'citation': 'Ceramic Technology Project Data...         Si-N:La
# 4093  [{'citation': 'The Zirconium-Zirconium Carbide...            Zr-C
# 4094  [{'citation': 'Engineering Properties of Nitri...            Al-N
# 4095  [{'citation': 'Creep in Yttria- and Scandia-St...         Zr-O:Sc
# 4096  [{'citation': 'Effect of Surface Condition on ...      Si-N:MgO,Y
# 4097  [{'citation': 'Ceramic Technology Project Data...        Al-O:CeO
# 4098  [{'citation': 'Cubic Boron Nitride:  Synthesis...             B-N
#
#                               flatFormula
# 1                               Si1.0O2.0
# 2     Al6.0O9.0Si2.0O4.0Zr0.1O0.2Y0.2O0.3
# 3                               Al2.0O3.0
# 4             Si3.0N4.0Ce0.1O0.2Si0.1C0.1
# 5                               Si3.0N4.0
# 6                       Zr1.0O2.0Y0.2O0.3
# 7                       Zr1.0O2.0Y0.2O0.3
# 8                               Si3.0N4.0
# 9                               Si1.0O2.0
# 10             Si3.0N4.0Y0.2O0.3Sr0.1O0.1
# 11                              Si1.0C1.0
# 12                              Si3.0N4.0
# 13                              Si3.0N4.0
# 14               Si11.6Al0.5O0.2N15.8D0.1
# 15                              Si1.0C1.0
# 16                              Si1.0C1.0
# 17                         Al4.2Si1.8O9.9
# 18                     Si1.0C1.0Ti0.1B0.2
# 19                              Ni1.0O1.0
# 20                     Si5.9Al0.1O0.1N7.9
# 21                              Si1.0C1.0
# 22             Zr1.0O2.0Y0.2O0.3Fe0.2O0.3
# 23                              Zr1.0O2.0
# 24                              Zr1.0B2.0
# 25                Al4.2Si1.8O9.9Zr0.1O0.2
# 26                              Al2.0O3.0
# 27                              Hf1.0B2.0
# 28                               B4.0C1.0
# 29                     Al2.0O3.0Zr0.1O0.2
# 30                               B1.0N1.0
# ...                                   ...
# 4069                       Ti1.0B2.0Ni0.1
# 4070                   Al6.0O9.0Si2.0O4.0
# 4071                       La2.0Zr2.0O7.0
# 4072                            Si3.0N4.0
# 4073                            Be1.0O1.0
# 4074                    Zr1.0O2.0Y0.2O0.3
# 4075                   Al0.2O0.3Si0.1O0.2
# 4076                    Si3.0N4.0Y0.2O0.3
# 4077                   Al0.2O0.3Si0.1O0.2
# 4078                            Al2.0O3.0
# 4079                            Si1.0C1.0
# 4080                            Al1.0N1.0
# 4081                            Si1.0C1.0
# 4082                            Ti2.0O3.0
# 4083                            Si1.0C1.0
# 4084                   Al2.0O3.0Mg0.1O0.1
# 4085                   Hf1.0O2.0Gd0.2O0.3
# 4086                            Mg1.0O1.0
# 4087                            Si3.0N4.0
# 4088                   Be1.0O1.0Al0.2O0.3
# 4089                            Ta1.0B2.0
# 4090                             B1.0N1.0
# 4091                            Al2.0O3.0
# 4092          Si3.0N4.0La0.2O0.3Sr0.1O0.1
# 4093                            Zr1.0C0.1
# 4094                            Al1.0N1.0
# 4095                   Zr1.0O2.0Sc0.2O0.3
# 4096           Si3.0N4.0Mg0.1O0.1Y0.2O0.3
# 4097          Al2.0O3.0Ce0.1O0.2Zr0.1O0.2
# 4098                             B1.0N1.0
#
# [4098 rows x 5 columns]

# %%
df1["composition"] =df1["flatFormula"].transform(str_to_composition)
df1.dropna(axis=1).head()
# Out:
#             chemicalFormula                   licenses  \
# 1                      SiO2  [{'name': 'NIST_SRD-30'}]
# 2  3Al2O3.2SiO2.xZrO2.yY2O3  [{'name': 'NIST_SRD-30'}]
# 3                     Al2O3  [{'name': 'NIST_SRD-30'}]
# 4          Si3N4.xCeO2.ySiC  [{'name': 'NIST_SRD-30'}]
# 5                     Si3N4  [{'name': 'NIST_SRD-30'}]
#
#                                           references Chemical Family  \
# 1  [{'citation': 'Gaseous Corrosion of Ceramics, ...            Si-O
# 2  [{'citation': 'Thermal Diffusivity/Conductivit...     Al-Si-O:ZrO
# 3  [{'citation': 'Mechanical Properties of Pure, ...            Al-O
# 4  [{'citation': 'Effect of Silicon Carbide Whisk...        Si-N:CeO
# 5  [{'citation': 'Corrosion of Silicon Nitride Ce...            Si-N
#
#                            flatFormula         composition
# 1                            Si1.0O2.0             (O, Si)
# 2  Al6.0O9.0Si2.0O4.0Zr0.1O0.2Y0.2O0.3  (Zr, O, Al, Si, Y)
# 3                            Al2.0O3.0             (O, Al)
# 4          Si3.0N4.0Ce0.1O0.2Si0.1C0.1   (O, Ce, Si, C, N)
# 5                            Si3.0N4.0             (Si, N)

# %%
#check the composition object
df1.loc[4,'composition']
# Out:
# Comp: Ce0.1 Si3.1 C0.1 N4 O0.2
